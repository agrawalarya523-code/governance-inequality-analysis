# %%
setwd("/Users/aryaagrawal/Coding/Projects/econ-analysis-project/data/processed")
long_form <- read.csv("long_form.csv")

# %%
cor.test(long_form$GINI, long_form$Education_Spend, method = "pearson")
# Out:
# 	Pearson's product-moment correlation
#
# data:  long_form$GINI and long_form$Education_Spend
# t = -7.7479, df = 1433, p-value = 1.758e-14
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.2496725 -0.1503282
# sample estimates:
#        cor
# -0.2005157

# %%
model <- lm(GINI ~ Education_Spend, data = long_form)
summary(model)
# Out:
# Call:
# lm(formula = GINI ~ Education_Spend, data = long_form)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -13.921  -5.814  -2.049   4.628  28.504
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)      41.1624     0.6518  63.153  < 2e-16 ***
# Education_Spend  -1.0312     0.1331  -7.748 1.76e-14 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7.876 on 1433 degrees of freedom
# Multiple R-squared:  0.04021,	Adjusted R-squared:  0.03954
# F-statistic: 60.03 on 1 and 1433 DF,  p-value: 1.758e-14
